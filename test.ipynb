# %%
import os
import pandas as pd

# %%
# Out:
#   application_id  customer_id application_date  requested_amount  \
# 0     APP-500000  CUST-100000       31/05/2021          125100.0
# 1     APP-500001  CUST-100001       2021-04-15           36900.0
# 2     APP-500002  CUST-100002       15/01/2023          353500.0
# 3     APP-500003  CUST-100003       2022-09-24          247800.0
# 4     APP-500004  CUST-100004            44944           66500.0
#
#    loan_term_months  declared_income employment_type  employer_name  \
# 0                36           7430.0   self employed            NaN
# 1                36          15064.0    Not Employed            NaN
# 2                24          21344.0        SALARIED  Employer_0575
# 3                12          28415.0     FT-Salaried  Employer_2232
# 4                60           5235.0          Salary  Employer_1268
#
#      emirate product_id branch_id channel app_form_version
# 0        DXB     PRD-04   BR-DXB1  Branch               v1
# ...
